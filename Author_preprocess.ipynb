# %% [markdown]
# ### 这部分对训练集和测试集做相同的预处理。
# 大概可以理解为特征工程

# %%
import pandas as pd
filepath = 'C:/Users\Administrator\Desktop/'

# %%
train_data = pd.read_csv(filepath+'train.csv')
test_data = pd.read_csv(filepath+'test.csv')

# %%
data_combine = pd.concat((train_data,test_data),axis=0)

# %%
data_combine.describe()
# Out:
#        author       id                                               text
# count   19579    27971                                              27971
# unique      3    27971                                              27971
# top       EAP  id20584  When age fell upon the world, and wonder went ...
# freq     7900        1                                                  1

# %% [markdown]
# 训练集也没有缺失值

# %%
import nltk

# %%
data_combine['word_split'] = data_combine.text.apply(lambda x:nltk.word_tokenize(x))

# %%
# %time
data_combine['text_len'] = data_combine.word_split.apply(lambda x:len(x))
# Out:
# Wall time: 0 ns

# %%
# 添加第一个特征：句子长度
data_combine = data_combine.drop('word_len',axis=1)

# %%
# 添加第二个特征：标点符号个数
symbol = [',','.','?',':',"'"]
def get_symbol_num(x):
    s = 0
    for i in x:
        if i in symbol:
            s+=1
    return s
data_combine['symbol_num'] = data_combine.word_split.apply(lambda x:get_symbol_num(x))

# %%
# 添加第3-7个特征：各个标点符号的个数
def get_each_symbol_num(x,i):
    s = 0
    for j in x:
        if j==i:
            s+=1
    return s
for i in symbol:
    data_combine['symbol_num_'+i] = data_combine.word_split.apply(lambda x:get_each_symbol_num(x,i))

# %%
data_combine = data_combine.drop('symbol_num_"',axis=1)

# %%
from nltk import WordNetLemmatizer

# %%
# 添加第8特征：stopword词个数
# %time
from nltk.corpus import stopwords
stopword = stopwords.words()
def get_num(x,y):
    s = 0
    for i in x:
        if i.lower() in y or WordNetLemmatizer().lemmatize(i.lower()) in y:
            s+=1
    return s
data_combine['stopword_num'] = data_combine.word_split.apply(lambda x:get_num(x,stopword))
# Out:
# Wall time: 0 ns

# %%
# 添加第9个特征：单词平均长度
def avg(x):
    s = 0
    l = 0
    for i in x:
        if i not in symbol:
            s+=len(i)
            l+=1
    return s/l
data_combine['word_mean_length'] = data_combine.word_split.apply(lambda x:avg(x))
# %time
# Out:
# Wall time: 0 ns

# %%
# 添加第10个特征：字母个数
def char_sum(x):
    s = 0
    for i in x:
        if i not in symbol:
            s+=len(i)
    return s
data_combine['char_num'] = data_combine.word_split.apply(lambda x:char_sum(x))

# %%
# 添加第11个特征：不重复出现的单词个数
def unique(x):
    a = []
    for i in x:
        if i not in symbol:
            a.append(i)
    return(len(set(a)))
data_combine['unique_word'] = data_combine.word_split.apply(lambda x:unique(x))

# %% [markdown]
# 接下来要处理挖掘出来的那些有区分性的单词，目前有下面这么三种想法
# * 直接把其中有代表性的单词取出来做一个one-hot型的变量
# * 把这些单词做一次SVD后放进去
# http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html
# * 先用一个简单模型针对这些单词特征做一次训练，把结果作为最终模型的特征
# 我还在想用哪一种方法，或许在使用集成学习的时候我们可以这样不同的操作数据集。
#
# 我先做tfidf
# 这里要用一个sklearn里面的tf-idf模型，这个模型的好处在于它可以自动帮你把ngram也做了，不用自己再额外做ngram。
# 具体可以参考http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(ngram_range=(1,4),analyzer='word',stop_words='english',lowercase=True)

# %%
tfidf.fit(data_combine.text.values.tolist())
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 4), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=25,algorithm='arpack')

# %%
svd_matrix = svd.fit_transform(tfidf.transform(data_combine.text.values.tolist()))

# %%
svd_feature = pd.DataFrame(svd_matrix)

# %%
svd_feature.columns = ['svd_word_1to4gram_'+str(i)for i in range(25)]

# %%
data_combine = data_combine.reset_index()

# %%
data_combine = pd.concat([data_combine,svd_feature],axis=1)

# %%
# 接下来做一个字母层次的tfidf的特征
tfidf_char = TfidfVectorizer(analyzer='char',lowercase=True,stop_words='english',ngram_range=(1,5))
tfidf_char.fit(data_combine.text.values.tolist())
svd_char = TruncatedSVD(n_components=25,algorithm='randomized')
svd_char_matrix = svd.fit_transform(tfidf_char.transform(data_combine.text.values.tolist()))
svd_char_feature = pd.DataFrame(svd_char_matrix)

# %%
svd_char_feature.columns = ['svd_char_1to5gram_'+str(i) for i in range(25)]

# %%
data_combine = pd.concat([data_combine,svd_char_feature],axis=1)

# %%
data_combine = data_combine.drop('index',axis=1)

# %% [markdown]
# 关于pandas保存为csv可以查看官方文档：http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html

# %%
data_combine.to_csv(filepath+'Dec_3.csv',index=False)

# %%
data_combine
# Out:
#       author       id                                               text  \
# 0        EAP  id26305  This process, however, afforded me no means of...
# 1        HPL  id17569  It never once occurred to me that the fumbling...
# 2        EAP  id11008  In his left hand was a gold snuff box, from wh...
# 3        MWS  id27763  How lovely is spring As we looked from Windsor...
# 4        HPL  id12958  Finding nothing else, not even gold, the Super...
# 5        MWS  id22965  A youth passed in solitude, my best years spen...
# 6        EAP  id09674  The astronomer, perhaps, at this point, took r...
# 7        EAP  id13515        The surcingle hung in ribands from my body.
# 8        EAP  id19322  I knew that you could not say to yourself 'ste...
# 9        MWS  id00912  I confess that neither the structure of langua...
# 10       MWS  id16737  He shall find that I can feel my injuries; he ...
# 11       EAP  id16607  Here we barricaded ourselves, and, for the pre...
# 12       HPL  id19764  Herbert West needed fresh bodies because his l...
# 13       HPL  id18886  The farm like grounds extended back very deepl...
# 14       EAP  id17189   But a glance will show the fallacy of this idea.
# 15       MWS  id12799  He had escaped me, and I must commence a destr...
# 16       EAP  id08441  To these speeches they gave, of course, their ...
# 17       MWS  id13117  Her native sprightliness needed no undue excit...
# 18       EAP  id14862  I even went so far as to speak of a slightly h...
# 19       HPL  id20836  His facial aspect, too, was remarkable for its...
# 20       EAP  id11411  Now the net work was not permanently fastened ...
# 21       HPL  id08075  It was not that the sounds were hideous, for t...
# 22       EAP  id18925  On every hand was a wilderness of balconies, o...
# 23       EAP  id19925  With how deep a spirit of wonder and perplexit...
# 24       EAP  id01704  These bizarre attempts at explanation were fol...
# 25       EAP  id10125  For many prodigies and signs had taken place, ...
# 26       EAP  id02448  All that as yet can fairly be said to be known...
# 27       EAP  id23451  I seemed to be upon the verge of comprehension...
# 28       HPL  id27907  Our compasses, depth gauges, and other delicat...
# 29       HPL  id08121  This the young warriors took back with them to...
# ...      ...      ...                                                ...
# 27941    NaN  id22510  Then again he distracted my thoughts from my s...
# 27942    NaN  id19204  Upon the whole, whether happily or unhappily, ...
# 27943    NaN  id05758  He was not allowed to finish this speech in tr...
# 27944    NaN  id27063  His looks were wild with terror, and he spoke ...
# 27945    NaN  id11773  By the quantity of provision which I had consu...
# 27946    NaN  id11562  I hurled after the scoundrel these vehement wo...
# 27947    NaN  id16208  Notwithstanding the hazardous object of our jo...
# 27948    NaN  id04036  I felt the greatest eagerness to hear the prom...
# 27949    NaN  id26159  But in the expression of the countenance, whic...
# 27950    NaN  id26777  Its decorations were rich, yet tattered and an...
# 27951    NaN  id08501  He directed my attention to some object agains...
# 27952    NaN  id11216  Hey? Haow'd ye like to hear the haowlin' night...
# 27953    NaN  id03410  She was buried not in a vault, but in an ordin...
# 27954    NaN  id04537  In company with this sprightly and clever Gree...
# 27955    NaN  id26628  In this unnerved in this pitiable condition I ...
# 27956    NaN  id01586  He was a scoundrel, and I don't blame you for ...
# 27957    NaN  id13421  But why should I dwell upon the incidents that...
# 27958    NaN  id26084  In the streets were spears of long grass, and ...
# 27959    NaN  id05375  When I first sought it, it was the love of vir...
# 27960    NaN  id23212  But it is in matters beyond the limits of mere...
# 27961    NaN  id15980  "I may say an excellently well constructed house.
# 27962    NaN  id11719  Across a covered bridge one sees a small villa...
# 27963    NaN  id13109  You cannot take up a common newspaper in which...
# 27964    NaN  id07156  Consoling myself with this reflection, I was m...
# 27965    NaN  id04893  Yet we laughed and were merry in our proper wa...
# 27966    NaN  id11749         All this is now the fitter for my purpose.
# 27967    NaN  id10526                 I fixed myself on a wide solitude.
# 27968    NaN  id13477  It is easily understood that what might improv...
# 27969    NaN  id13761  Be this as it may, I now began to feel the ins...
# 27970    NaN  id04282  Long winded, statistical, and drearily genealo...
#
#                                               word_split  text_len  \
# 0      [This, process, ,, however, ,, afforded, me, n...        48
# 1      [It, never, once, occurred, to, me, that, the,...        15
# 2      [In, his, left, hand, was, a, gold, snuff, box...        41
# 3      [How, lovely, is, spring, As, we, looked, from...        38
# 4      [Finding, nothing, else, ,, not, even, gold, ,...        31
# 5      [A, youth, passed, in, solitude, ,, my, best, ...        90
# 6      [The, astronomer, ,, perhaps, ,, at, this, poi...        26
# 7      [The, surcingle, hung, in, ribands, from, my, ...         9
# 8      [I, knew, that, you, could, not, say, to, your...        98
# 9      [I, confess, that, neither, the, structure, of...        26
# 10     [He, shall, find, that, I, can, feel, my, inju...        25
# 11     [Here, we, barricaded, ourselves, ,, and, ,, f...        13
# 27950             -0.024348              0.033104              0.008080
# 27951              0.017140             -0.009302              0.075521
# 27952              0.006813              0.044266              0.056603
# 27953             -0.005503             -0.012822              0.009718
# 27954             -0.031387             -0.031356              0.008806
# 27955             -0.077609              0.016412              0.020302
# 27956              0.024403             -0.057773              0.003127
# 27957             -0.084927              0.022035              0.039217
# 27958             -0.045083              0.016933              0.028691
# 27959             -0.024806              0.001849              0.021758
# 27960             -0.022890             -0.013108             -0.037403
# 27961              0.026288              0.009911              0.059401
# 27962              0.003498             -0.028422              0.013925
# 27963              0.083687              0.008705              0.093828
# 27964             -0.010060             -0.008532              0.023550
# 27965              0.051295              0.076630             -0.009951
# 27966             -0.100279              0.053238             -0.019510
# 27967             -0.012641             -0.005679              0.019402
# 27968              0.019646              0.019475             -0.018894
# 27969             -0.034713              0.024986              0.007107
# 27970              0.034797              0.048852             -0.023608
#
#        svd_char_1to5gram_23  svd_char_1to5gram_24
# 0                 -0.002864              0.001790
# 1                  0.028587             -0.001092
# 2                 -0.027592             -0.022302
# 3                 -0.006246              0.016567
# 4                  0.062051             -0.009140
# 5                  0.023744              0.062683
# 6                  0.002735             -0.044457
# 7                  0.005835             -0.057799
# 8                  0.026296              0.011625
# 9                 -0.085298              0.042077
# 10                 0.020599              0.055210
# 11                -0.043207              0.017850
# 12                 0.012060             -0.019385
# 13                 0.047121             -0.016109
# 14                 0.055883              0.021437
# 15                -0.009399              0.014461
# 16                -0.033537              0.018872
# 17                 0.037563              0.006938
# 18                 0.019508             -0.022553
# 19                 0.024743              0.012637
# 20                 0.015555              0.004814
# 21                 0.035114              0.020326
# 22                 0.006675              0.040479
# 23                -0.043783             -0.029846
# 24                 0.027024             -0.031779
# 25                -0.043577              0.040451
# 26                 0.018124              0.025271
# 27                -0.040307             -0.090756
# 28                -0.002247             -0.037734
# 29                -0.047684              0.030912
# ...                     ...                   ...
# 27941              0.029548             -0.104423
# 27942              0.012473             -0.036768
# 27943              0.063317              0.051423
# 27944             -0.038903             -0.004018
# 27945             -0.009801              0.000513
# 27946              0.037443              0.036346
# 27947              0.042216              0.030253
# 27948              0.006947             -0.004412
# 27949              0.041227             -0.031218
# 27950              0.006414              0.000926
# 27951              0.016558             -0.087681
# 27952              0.013236             -0.024453
# 27953              0.055365             -0.011852
# 27954              0.025597             -0.070492
# 27955             -0.031168             -0.023225
# 27956              0.038389             -0.036548
# 27957              0.048052              0.013075
# 27958             -0.071639              0.006695
# 27959             -0.010629              0.083839
# 27960              0.004548              0.017799
# 27961              0.060431             -0.063482
# 27962              0.001941              0.023433
# 27963              0.006190             -0.016079
# 27964             -0.033619             -0.036962
# 27965              0.020010              0.059308
# 27966              0.023474              0.076282
# 27967             -0.026950             -0.010825
# 27968              0.004511             -0.012732
# 27969             -0.012193              0.008207
# 27970             -0.020781              0.027422
#
# [27971 rows x 65 columns]
